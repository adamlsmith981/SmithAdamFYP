# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data_6 = [[float(i) for i in l.split()] for l in open("ecutwfc_CT/data.txt",'r').readlines()[4:]]

# %%
ecutwfc1, energy1 = zip(*data_6)

# %%
plt.plot(ecutwfc1, energy1)
font1 = {'family':'serif','color':'Black','size':12}
font2 = {'family':'serif','color':'Black','size':11}
plt.title("Ta2CH2 - varying kinetic energy cut off",fontdict = font1)
plt.xlabel("ecutwfc Ry",fontdict = font2)
plt.ylabel("Total Energy Ry",fontdict = font2)
plt.ticklabel_format(useOffset=False)
plt.show()
plt.savefig('MoS2_CT_ecut.png')

# %%
energy1
# Out:
# (-1375.69598274,
#  -1375.69710885,
#  -1375.69757947,
#  -1375.69805174,
#  -1375.69865485,
#  -1375.69929719,
#  -1375.69983967,
#  -1375.70019697,
#  -1375.70038473,
#  -1375.7004712,
#  -1375.70052372,
#  -1375.70058624,
#  -1375.70067158,
#  -1375.70077363,
#  -1375.70087743,
#  -1375.7009739,
#  -1375.70105486,
#  -1375.7011192,
#  -1375.70116988,
#  -1375.70120847,
#  -1375.70123862,
#  -1375.70126244,
#  -1375.70128243,
#  -1375.70130004,
#  -1375.70131655,
#  -1375.70137139,
#  -1375.70145204,
#  -1375.70149084,
#  -1375.70150587,
#  -1375.70153346,
#  -1375.70155913)
