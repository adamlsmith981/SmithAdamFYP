# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# data = []
# for l in open("changing k points results.txt",'r').readlines():
#     data.append([i for i in l.split()])
# data.pop(0)

# %%
data = [[float(i) for i in l.split()] for l in open("lat_const_CT/data.txt",'r').readlines()[4:]]

# %%
lat_const, energy = zip(*data)

# %%
plt.plot(lat_const, energy)
font1 = {'family':'serif','color':'Black','size':12}
font2 = {'family':'serif','color':'Black','size':11}
plt.title("Ta2CO2 - Convergence lattice const",fontdict=font1)
plt.xlabel("lattice constant (Bohr)",fontdict = font2)
plt.ylabel("Total Energy (Ry)",fontdict = font2)
plt.ticklabel_format(useOffset=False)
plt.show()
plt.savefig('Ta2CO2_CT_alat.png')
